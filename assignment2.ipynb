# %% [raw]
# 1.True,False
#
# 2.and, or, and not
#
# 3. and : True True :  True       or  : True True : True        not : True  : False
#             True False : False          : True False  : True          : False : True
#             False True : False          : False True  : True
#             False False : False         : False False : False

# %%
#4.
(5>4) and (3==5)
# Out:
# False

# %%
#4.
not(5>4)
# Out:
# False

# %%
#4.
(5>4) or (3==5)
# Out:
# True

# %%
#4/
not((5>4) or (3==5))
# Out:
# False

# %%
#4.
(True and True) and (True==False)
# Out:
# False

# %%
#4.
not(False) or not(True)
# Out:
# True

# %% [markdown]
#  5.     >,<,>=,<=,==,!=
#  6.      =  is assignment opeartor it is used to aign the value to the variable ex: x = 5
#          ==  it is used to compare to values it checks and returns 1 if both values are equal

# %%
spam = 0
if spam == 10:
    print('eggs')
if spam >5:
    print('bacon')
else:
    print('ham')
    print('spam')
    print('spam')
# Out:
# ham
# spam
# spam

# %%
spam = 0
if spam == 1:
    print('Hello')
if spam == 2:
    print('Howdy')
else:
    print('Greetings')
# Out:
# Greetings

# %%
#9 ctrl+c
i=1
while(i==1):
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %% [markdown]
# #10.
#  Break    : break statement is used to break/ or terminate the enclosing loop
#  continue : it will skip the rest of the loop and execute the next iteration
